# %% [markdown]
# **TASK 6**
# ##**Prediction using Decision Tree Algorithm**
#
#
#
# ● Create the Decision Tree classifier and visualize it graphically.
#
# ● The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# ● Imported Data from : https://bit.ly/3kXTdox

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics

# %% [markdown]
# **Reading the Data**

# %%
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'Outcome']
df = pd.read_csv("Iris.csv", header=None, names=col_names)
print("Data Imported Successfully")
# Out:
# Data Imported Successfully

# %% [markdown]
# **Visualizing the Data**

# %%
df.info()
df = df.iloc[1:]
print()
print("The first Five Tuples of the Data:")
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, Id to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  151 non-null    object
#  1   sepal_width   151 non-null    object
#  2   petal_length  151 non-null    object
#  3   petal_width   151 non-null    object
#  4   Outcome       151 non-null    object
# dtypes: object(5)
# memory usage: 7.1+ KB
#
# The first Five Tuples of the Data:
#   sepal_length sepal_width petal_length petal_width      Outcome
# 1          5.1         3.5          1.4         0.2  Iris-setosa
# 2          4.9         3.0          1.4         0.2  Iris-setosa
# 3          4.7         3.2          1.3         0.2  Iris-setosa
# 4          4.6         3.1          1.5         0.2  Iris-setosa
# 5          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# **Preparing for Training and Testing Data**

# %%
feature_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df[feature_cols] 
y = df.Outcome

# %% [markdown]
# **Splitting the Data**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# **Accuracy Prediction using Decision Tree Classifer**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print("Accuracy Obtained is:",(metrics.accuracy_score(y_test, y_pred)))
# Out:
# Accuracy Obtained is: 0.9555555555555556

# %% [markdown]
# **Importing pydotplus for visualizing the Tree**

# %%
import pydotplus

# %% [markdown]
# **Graphical Representation of the data using Decison Tree Classifier**
#
# ● Desicion Tree of the Classified Data is saved locally as Iris.png using Graphviz module.

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
from pydotplus import graph_from_dot_data

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1','2'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('Iris.png')
Image(graph.create_png())

# %% [markdown]
# # **THANK YOU!**
